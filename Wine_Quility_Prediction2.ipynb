# %% [markdown]
# <h1>Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h3>Loading the dataset in a Pandas DataFrame

# %%
df = pd.read_csv('WineQuality.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %% [markdown]
# <h3>Getting Information about Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %% [markdown]
# <h3>Removing unwanted/useless Column form DataFrame

# %%
df = df.drop(['Id'], axis=1)

# %% [markdown]
# <h3>Checking for the missing values

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# <h2>Data Analysis and Visualization

# %% [markdown]
# <h3>Statistical Measurements

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043
# std       0.156664     0.170399     1.082196     0.805824
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.205000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# <h3>No. of Wines for Each Quality

# %%
sns.catplot(x='quality', data = df, kind='count')

# %% [markdown]
# <h3>Comparision of different columns with quality to find the relation between them

# %%
fig, axes = plt.subplots(1, 5, figsize=(15, 5), sharey=True)
sns.barplot(ax=axes[0], x='quality', y='fixed acidity', data=df)
sns.barplot(ax=axes[1], x='quality', y='volatile acidity', data = df)
sns.barplot(ax=axes[2], x='quality', y='citric acid', data = df)
sns.barplot(ax=axes[3], x='quality', y='residual sugar', data = df)
sns.barplot(ax=axes[4], x='quality', y='chlorides', data = df)
# Out:
# <AxesSubplot: xlabel='quality', ylabel='chlorides'>

# %%
fig, axes = plt.subplots(1, 5, figsize=(15, 5), sharey=True)
sns.barplot(ax=axes[0], x='quality', y='free sulfur dioxide', data = df)
sns.barplot(ax=axes[1], x='quality', y='density', data = df)
sns.barplot(ax=axes[2], x='quality', y='pH', data = df)
sns.barplot(ax=axes[3], x='quality', y='sulphates', data = df)
sns.barplot(ax=axes[4], x='quality', y='alcohol', data = df)
# Out:
# <AxesSubplot: xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# <h3>Histogram to visualise the distribution of data with continuous values

# %%
df.hist(bins=50, figsize=(15, 10))
plt.show()

# %% [markdown]
# <h2>Constructing a Heatmap  to Understand the correlation between the columns

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(df.corr(), cbar=True, square=True, fmt='.1f', annot=True, cmap='Reds')
# Out:
# <AxesSubplot: >

# %% [markdown]
# <h1>Data Preprocessing
# <h2> Separating the data and label

# %%
X = df.drop(['quality'], axis=1)

# %% [markdown]
# <h1>Label Binarization

# %%
df['Best Quality'] = [1 if x>=7 else 0 for x in df.quality]
Y = df['Best Quality']

# %%
df['Best Quality'].value_counts()
# Out:
# 0    984
# 1    159
# Name: Best Quality, dtype: int64

# %% [markdown]
# <h3>Imbalanced Dataset

# %%
sns.countplot(Y)
# Out:
# <AxesSubplot: ylabel='count'>

# %%
df['Best Quality'].value_counts()
# Out:
# 0    984
# 1    159
# Name: Best Quality, dtype: int64

# %% [markdown]
# <h1>Train and Test Split

# %%
from sklearn.preprocessing import StandardScaler
X_feat = X
X = StandardScaler().fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.25, random_state=3)

# %%
print(Y.shape, Y_train.shape, Y_test.shape)
# Out:
# (1143,) (857,) (286,)

# %% [markdown]
# <h1>Model Training

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.90)
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.30190263, 0.16723906, 0.13684714, 0.11409233, 0.08092139,
#        0.0584542 , 0.05161847])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9110752283731481

# %% [markdown]
# <h3>Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred1 = log.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test, Y_pred1)
# Out:
# 0.8846153846153846

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93       237
#            1       0.81      0.43      0.56        49
#
#     accuracy                           0.88       286
#    macro avg       0.85      0.70      0.75       286
# weighted avg       0.88      0.88      0.87       286

# %% [markdown]
# SVM

# %%
from sklearn import svm
svm = svm.SVC()
svm.fit(X_train, Y_train)
# Out:
# SVC()

# %%
Y_pred2 = svm.predict(X_test)

# %%
accuracy_score(Y_test, Y_pred2)
print(classification_report(Y_test, Y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       237
#            1       0.91      0.20      0.33        49
#
#     accuracy                           0.86       286
#    macro avg       0.88      0.60      0.63       286
# weighted avg       0.87      0.86      0.82       286

# %%
# Filtering df for only best quality
df_temp = df[df['Best Quality']==1]
df_temp.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count     159.000000        159.000000   159.000000      159.000000
# mean        8.846541          0.395314     0.391195        2.748428
# std         2.097038          0.134869     0.195116        1.400818
# min         4.900000          0.120000     0.000000        1.200000
# 25%         7.400000          0.300000     0.320000        1.900000
# 50%         8.700000          0.360000     0.410000        2.300000
# 75%        10.100000          0.480000     0.520000        2.800000
# max        15.600000          0.850000     0.760000        8.300000
#
#         chlorides  free sulfur dioxide  total sulfur dioxide     density  \
# count  159.000000           159.000000            159.000000  159.000000
# mean     0.074711            14.188679             36.672956    0.996019
# std      0.029154             9.903279             35.612808    0.002283
# min      0.012000             3.000000              8.000000    0.990640
# 25%      0.062000             6.000000             18.000000    0.994610
# 50%      0.073000            12.000000             28.000000    0.995680
# 75%      0.083500            17.500000             43.000000    0.997350
# max      0.358000            53.000000            289.000000    1.003200
#
#                pH   sulphates     alcohol     quality  Best Quality
# count  159.000000  159.000000  159.000000  159.000000         159.0
# mean     3.282453    0.745849   11.528407    7.100629           1.0
# std      0.156297    0.141459    1.007960    0.301787           0.0
# min      2.880000    0.390000    9.200000    7.000000           1.0
# 25%      3.200000    0.660000   10.800000    7.000000           1.0
# 50%      3.270000    0.740000   11.600000    7.000000           1.0
# 75%      3.375000    0.835000   12.250000    7.000000           1.0
# max      3.780000    1.360000   14.000000    8.000000           1.0

# %%
# Filtering df for only bad quality
df_temp2 = df[df['Best Quality']==0]
df_temp2.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count     984.000000        984.000000   984.000000      984.000000
# mean        8.224593          0.553318     0.248516        2.497205
# std         1.669548          0.176316     0.189707        1.345994
# min         4.600000          0.160000     0.000000        0.900000
# 25%         7.100000          0.430000     0.080000        1.900000
# 50%         7.800000          0.550000     0.240000        2.200000
# 75%         9.000000          0.660000     0.400000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#         chlorides  free sulfur dioxide  total sulfur dioxide     density  \
# count  984.000000           984.000000            984.000000  984.000000
# mean     0.088908            15.846037             47.408028    0.996845
# std      0.049304            10.291822             32.071725    0.001836
# min      0.034000             1.000000              6.000000    0.990070
# 25%      0.071000             7.000000             22.000000    0.995727
# 50%      0.080000            14.000000             39.000000    0.996765
# 75%      0.091000            21.000000             64.000000    0.997900
# max      0.611000            68.000000            165.000000    1.003690
#
#                pH   sulphates     alcohol     quality  Best Quality
# count  984.000000  984.000000  984.000000  984.000000         984.0
# mean     3.315630    0.643465   10.266582    5.423780           0.0
# std      0.156313    0.170459    0.987707    0.590087           0.0
# min      2.740000    0.330000    8.400000    3.000000           0.0
# 25%      3.210000    0.540000    9.500000    5.000000           0.0
# 50%      3.315000    0.600000   10.000000    5.000000           0.0
# 75%      3.410000    0.692500   10.900000    6.000000           0.0
# max      4.010000    2.000000   14.900000    6.000000           0.0
